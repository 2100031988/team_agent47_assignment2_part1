# %%
# NumCompute Quickstart Demo

"""
This notebook demonstrates the usage of the NumCompute framework:
- CSV loading
- Preprocessing
- Statistics
- Sorting & Ranking
- Metrics
- Optimization
- Pipeline usage
"""
# Out:
# '\nThis notebook demonstrates the usage of the NumCompute framework:\n- CSV loading\n- Preprocessing\n- Statistics\n- Sorting & Ranking\n- Metrics\n- Optimization\n- Pipeline usage\n'
